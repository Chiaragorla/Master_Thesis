# %% [markdown]
# # Load the data

# %% [markdown]
# Train set

# %%
import pandas as pd
train = pd.read_pickle(r"C:\Users\Utente\Desktop\Chiara\SUBSET\df_train_mean.pkl")

# %%
train
# Out:
#                                                  signals  \
# 0      [[-0.8528068545596585, -1.059697163453328, -1....
# 1      [[1.3934307848573246, 1.4525423016840873, 1.54...
# 2      [[-0.37991471994555687, -0.43902623677231956, ...
# 3      [[6.151907889411723, 6.033684855758198, 5.9154...
# 4      [[-0.557249270425845, -0.46858199518570093, -0...
# ...                                                  ...
# 20968  [[-1.887258399028006, -2.0350371910949128, -1....
# 20969  [[-0.20258016946526872, -0.17302441105188737, ...
# 20970  [[0.15208893149530758, 0.0634216562551635, -0....
# 20971  [[0.5363137908692652, 0.595425307696028, 0.270...
# 20972  [[2.989441739179918, 3.048553256006681, 3.0781...
#
#                          ID_paz    y
# 0                 Napoli_2013_5  266
# 1                 Napoli_2013_6  272
# 2                 Napoli_2013_6  277
# 3                 Napoli_2013_6  265
# 4                 Napoli_2013_8  255
# ...                         ...  ...
# 20968    archivio_2013_a12_9146  285
# 20969  archivio_07_04_2011_1274  262
# 20970  archivio_07_04_2011_4315  239
# 20971  archivio_07_04_2011_4315  246
# 20972       archivio_05_08_2570  284
#
# [20973 rows x 3 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
values, counts = np.unique(train['y'], return_counts=True)

plt.figure(figsize=(12,6))
plt.bar(values, counts, color='lightcoral', edgecolor='black', width=0.8)
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Barplot of value frequencies of the scaled values of the gestational age in the training set")
plt.show()

# %%
train_q_a = pd.read_pickle(r"C:\Users\Utente\Desktop\Chiara\DockerImage\softmax_predictions_train_non_norm.pkl")
print(train_q_a)
# Out:
#                                  softmax_prediction_list
# 0      [0.020972391590476036, 0.021176209673285484, 0...
# 1      [0.8710892200469971, 0.8681394457817078, 0.855...
# 2      [0.8702703714370728, 0.8699919581413269, 0.848...
# 3      [0.995213508605957, 0.9948815703392029, 0.9920...
# 4      [0.611287534236908, 0.6111699342727661, 0.5913...
# ...                                                  ...
# 20968  [0.9769368171691895, 0.9769885540008545, 0.966...
# 20969  [0.9871559143066406, 0.9871239066123962, 0.981...
# 20970  [0.9252670407295227, 0.9244728684425354, 0.906...
# 20971  [0.6727402210235596, 0.6682286858558655, 0.651...
# 20972  [0.7778903245925903, 0.7595663666725159, 0.744...
#
# [20973 rows x 1 columns]

# %% [markdown]
# Validation set

# %%
val = pd.read_pickle(r"C:\Users\Utente\Desktop\Chiara\SUBSET\df_val_mean.pkl")

# %%
val
# Out:
#                                                 signals  \
# 0     [[0.12253317308192621, 0.18164468990868893, 0....
# 1     [[2.3096592956721467, 2.7234399134594858, 2.72...
# 2     [[5.2061236201835195, 4.7627872439828, 4.76278...
# 3     [[3.7578914579278333, 4.053449042061647, 3.964...
# 4     [[2.339215054085528, 2.4574380877390536, 2.486...
# ...                                                 ...
# 2269  [[-1.0301414050399467, -1.0301414050399467, -1...
# 2270  [[1.8072114026446635, 1.8072114026446635, 2.01...
# 2271  [[0.270311965148833, 0.270311965148833, 0.2703...
# 2272  [[-0.557249270425845, -0.557249270425845, -0.5...
# 2273  [[0.4772022740425025, 0.4772022740425025, 0.47...
#
#                       ID_paz    y
# 0             Napoli_2013_71  272
# 1             Napoli_2013_71  256
# 2            Napoli_2013_108  283
# 3            Napoli_2013_108  294
# 4            Napoli_2013_108  292
# ...                      ...  ...
# 2269   archivio_290113_10796  266
# 2270   archivio_290113_10796  274
# 2271   archivio_290113_10864  260
# 2272   archivio_290113_10907  250
# 2273  archivio_2013_a12_8487  268
#
# [2274 rows x 3 columns]

# %%
values, counts = np.unique(val['y'], return_counts=True)

plt.figure(figsize=(12,6))
plt.bar(values, counts, color='lightcoral', edgecolor='black', width=0.8)
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Barplot of value frequencies of the scaled values of the gestational age in the validation set")
plt.show()

# %%
val_q_a = pd.read_pickle(r"C:\Users\Utente\Desktop\Chiara\DockerImage\softmax_predictions_val_non_norm.pkl")
print(val_q_a)
# Out:
#                                 softmax_prediction_list
# 0     [0.98567134141922, 0.9855837821960449, 0.97904...
# 1     [0.9937933087348938, 0.9934059381484985, 0.990...
# 2     [0.8583760261535645, 0.8466813564300537, 0.832...
# 3     [0.9709763526916504, 0.9683090448379517, 0.956...
# 4     [0.7831006646156311, 0.7729586958885193, 0.757...
# ...                                                 ...
# 2269  [0.8998614549636841, 0.9001203179359436, 0.874...
# 2270  [0.982734739780426, 0.9823014736175537, 0.9768...
# 2271  [0.03486759215593338, 0.035138554871082306, 0....
# 2272  [0.3863846957683563, 0.38645949959754944, 0.39...
# 2273  [0.9937825202941895, 0.9936987161636353, 0.990...
#
# [2274 rows x 1 columns]

# %% [markdown]
# Test set of healthy patients

# %%
test = pd.read_pickle(r"C:\Users\Utente\Desktop\Chiara\SUBSET\df_test_mean.pkl")

# %%
test
# Out:
#                                                 signals  \
# 0     [[0.6249810661094093, 0.44764651562912117, 0.5...
# 1     [[1.009205925483367, 0.8318713750030788, 0.861...
# 2     [[3.137220531246825, 3.1963320480735873, 3.284...
# 3     [[2.1914362620186214, 2.3096592956721467, 2.36...
# 4     [[2.1914362620186214, 2.3983265709122907, 2.22...
# ...                                                 ...
# 2622  [[107.38038045524287, 106.87793256221539, 106....
# 2623  [[-0.5276935120124636, -0.5868050288392264, -0...
# 2624  [[-0.3503589615321755, -0.43902623677231956, -...
# 2625  [[2.782551430286248, 2.4574380877390536, 2.782...
# 2626  [[-1.7690353653744806, -1.7394796069610994, -1...
#
#                         ID_paz    y
# 0               Napoli_2013_35  258
# 1               Napoli_2013_35  250
# 2               Napoli_2013_44  247
# 3               Napoli_2013_44  251
# 4               Napoli_2013_44  267
# ...                        ...  ...
# 2622     archivio_290113_10888  265
# 2623        archivio_2013_6578  268
# 2624    archivio_2013_a10_7601  280
# 2625    archivio_2013_a10_7623  263
# 2626  archivio_07_04_2011_4687  264
#
# [2627 rows x 3 columns]

# %%
values, counts = np.unique(test['y'], return_counts=True)

plt.figure(figsize=(12,6))
plt.bar(values, counts, color='lightcoral', edgecolor='black', width=0.8)
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Barplot of value frequencies of the scaled values of the gestational age in the test set")
plt.show()

# %%
test_q_a = pd.read_pickle(r"C:\Users\Utente\Desktop\Chiara\DockerImage\softmax_predictions_test_non_norm.pkl")
print(test_q_a)
# Out:
#                                 softmax_prediction_list
# 0     [0.18996216356754303, 0.18453121185302734, 0.2...
# 1     [0.5718382596969604, 0.5616149306297302, 0.569...
# 2     [0.9706099033355713, 0.9682478904724121, 0.959...
# 3     [0.6812413930892944, 0.663272500038147, 0.6672...
# 4     [0.8983632922172546, 0.8909948468208313, 0.881...
# ...                                                 ...
# 2622  [0.9999998211860657, 0.9999985098838806, 0.999...
# 2623  [0.9290224313735962, 0.9290343523025513, 0.906...
# 2624  [0.010340921580791473, 0.010674706660211086, 0...
# 2625  [0.9575894474983215, 0.9545063376426697, 0.945...
# 2626  [0.8504446744918823, 0.850551426410675, 0.8165...
#
# [2627 rows x 1 columns]

# %% [markdown]
# Test set of sick patients

# %%
test_sick = pd.read_pickle(r"C:\Users\Utente\Desktop\Chiara\SUBSET\df_malati_mean_noFMP.pkl")

# %%
test_sick
# Out:
#                                                 signals    y
# 0     [[-0.7345838209061332, -0.7936953377328959, -0...  288
# 1     [[-1.2961432307603789, -1.2665874723469976, -1...  273
# 2     [[-0.7936953377328959, -0.7641395793195145, -0...  264
# 3     [[-0.08435713581174328, -0.05480137739836193, ...  271
# 4     [[0.8614271334164602, 1.009205925483367, 0.861...  272
# ...                                                 ...  ...
# 2594  [[-0.3503589615321755, -0.2912474447054128, -0...  228
# 2595  [[0.35897924038897705, 0.35897924038897705, 0....  234
# 2596  [[-1.887258399028006, -1.709923848547718, -1.5...  281
# 2597  [[0.32942348197559573, 0.270311965148833, 0.32...  237
# 2598  [[1.4229865432707058, 1.3934307848573246, 1.36...  238
#
# [2599 rows x 2 columns]

# %%
values, counts = np.unique(test_sick['y'], return_counts=True)

plt.figure(figsize=(12,6))
plt.bar(values, counts, color='lightcoral', edgecolor='black', width=0.8)
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Barplot of value frequencies of the scaled values of the gestational age in the test set of fetuses affected by IUGR")
plt.show()

# %%
test_sick_q_a = pd.read_pickle(r"C:\Users\Utente\Desktop\Chiara\DockerImage\softmax_predictions_test_sick_non_norm.pkl")
print(test_sick_q_a)
# Out:
#                                 softmax_prediction_list
# 0     [0.8098800182342529, 0.8100842237472534, 0.785...
# 1     [0.8958796858787537, 0.8961122632026672, 0.868...
# 2     [0.2620459496974945, 0.26213929057121277, 0.27...
# 3     [0.7566676139831543, 0.7554646134376526, 0.719...
# 4     [0.126233771443367, 0.12223902344703674, 0.147...
# ...                                                 ...
# 2594  [0.07555071264505386, 0.07627912610769272, 0.0...
# 2595  [0.5935284495353699, 0.5886592268943787, 0.587...
# 2596  [0.9311527609825134, 0.9312254786491394, 0.910...
# 2597  [0.5107316970825195, 0.5067952871322632, 0.514...
# 2598  [0.47544220089912415, 0.4613264501094818, 0.48...
#
# [2599 rows x 1 columns]

# %%
train['signals'] = train['signals'].apply(lambda x: x[0] if isinstance(x, list) and isinstance(x[0], np.ndarray) else x)

# %%
val['signals'] = val['signals'].apply(lambda x: x[0] if isinstance(x, list) and isinstance(x[0], np.ndarray) else x)

# %%
test['signals'] = test['signals'].apply(lambda x: x[0] if isinstance(x, list) and isinstance(x[0], np.ndarray) else x)

# %%
test_sick['signals'] = test_sick['signals'].apply(lambda x: x[0] if isinstance(x, list) and isinstance(x[0], np.ndarray) else x)

# %%
test_sick
# Out:
#                                                 signals    y
# 0     [-0.7345838209061332, -0.7936953377328959, -0....  288
# 1     [-1.2961432307603789, -1.2665874723469976, -1....  273
# 2     [-0.7936953377328959, -0.7641395793195145, -0....  264
# 3     [-0.08435713581174328, -0.05480137739836193, -...  271
# 4     [0.8614271334164602, 1.009205925483367, 0.8614...  272
# ...                                                 ...  ...
# 2594  [-0.3503589615321755, -0.2912474447054128, -0....  228
# 2595  [0.35897924038897705, 0.35897924038897705, 0.4...  234
# 2596  [-1.887258399028006, -1.709923848547718, -1.56...  281
# 2597  [0.32942348197559573, 0.270311965148833, 0.329...  237
# 2598  [1.4229865432707058, 1.3934307848573246, 1.363...  238
#
# [2599 rows x 2 columns]

# %%
# Merging the FHR signals with the predictions of the pretrained model, 
# which are the activity state of each FHR signal

train = pd.concat([train, train_q_a], axis=1)
val = pd.concat([val, val_q_a], axis=1)
test = pd.concat([test, test_q_a], axis=1)
test_sick = pd.concat([test_sick, test_sick_q_a], axis=1)

# %% [markdown]
# Signals are already interpolated and Normalized

# %% [markdown]
# # Windowing of the signals

# %%
def find_n_windows(l_signal, w_window=3600, Maxoverlap=0.5):
    n_windows = np.ceil(l_signal / w_window)
    if n_windows ==1:
        overlap = 0
    else:
        overlap = np.ceil(((n_windows * w_window) - l_signal) / (n_windows -1))
    if overlap * (n_windows - 1) > (w_window * Maxoverlap):
        n_windows = n_windows -1
        overlap = 0
    return n_windows, overlap


#import numpy as np

def WindowSignals(X, y, Maxoverlap=0.5):
    
    if isinstance(X, pd.DataFrame) or isinstance(X, pd.Series):
        X = X.to_numpy()  # Convert to numpy array if X is a DataFrame or Series
    if isinstance(y, pd.DataFrame) or isinstance(y, pd.Series):
        y = y.to_numpy()  # Convert to numpy array if y is a DataFrame or Series
    

    X_post_win = []
    y_post_win = []

    for i in range(len(X)):  
        signal = X[i]
        label = y[i]  

        l_signal = len(signal)  
        w_window = 3600 

        # Calculates the number of windows and overlap based on the signal length and window size
        if Maxoverlap > 0:
            n_windows, overlap = find_n_windows(l_signal, w_window, Maxoverlap)
        else:
            n_windows = np.floor(l_signal / w_window)
            overlap = 0

        # Generate the windows
        for n in range(int(n_windows)):
            start_index = int(n * (w_window - overlap))
            end_index = int(start_index + w_window)
            if end_index > l_signal: 
                break
            window = signal[start_index:end_index]
            X_post_win.append(window)
            y_post_win.append(label)  # Appends the same label for all windows of the same signal

    return np.array(X_post_win, dtype=object), np.array(y_post_win, dtype=object)

# %%
# Windowing on the signals of the datasets
X_windows_train, y_windows_train= WindowSignals(train['signals'], train['y'])
X_windows_validation, y_windows_validation = WindowSignals(val['signals'], val['y'])
X_windows_test, y_windows_test = WindowSignals(test['signals'], test['y'])
X_windows_test_sick, y_windows_test_sick = WindowSignals(test_sick['signals'], test_sick['y'])

# %%
X_windows_train_qa, y_windows_train= WindowSignals(train['softmax_prediction_list'], train['y'])
X_windows_validation_qa, y_windows_validation = WindowSignals(val['softmax_prediction_list'], val['y'])
X_windows_test_qa, y_windows_test_qa = WindowSignals(test['softmax_prediction_list'], test['y'])
X_windows_test_sick_qa, y_windows_test_sick_qa = WindowSignals(test_sick['softmax_prediction_list'], test_sick['y'])

# %%
print(X_windows_train.shape)
#print(X_train.shape)
print(y_windows_train.shape)
#print(y_train.shape)
print(X_windows_train_qa.shape)
# Out:
# (27659, 3600)
# (27659,)
# (27659, 3600)

# %% [markdown]
# # Scaling of the gestational age

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(-1, 1))
scaler.fit(y_windows_train.reshape(-1, 1))

y_windows_train_scaled = scaler.transform(y_windows_train.reshape(-1, 1))
y_windows_validation_scaled = scaler.transform(y_windows_validation.reshape(-1, 1))
y_windows_test_scaled = scaler.transform(y_windows_test.reshape(-1, 1))
y_windows_test_sick_scaled = scaler.transform(y_windows_test_sick.reshape(-1, 1))

# %%
y_windows_train = y_windows_train_scaled
y_windows_validation = y_windows_validation_scaled
y_windows_test = y_windows_test_scaled
y_windows_test_sick = y_windows_test_sick_scaled

# %%
values, counts = np.unique(y_windows_train, return_counts=True)

plt.figure(figsize=(12,6))
plt.bar(values, counts, color='lightcoral', edgecolor='black', width=0.1)
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Barplot of value frequencies of the scaled values of the gestational age in the training set after windowing of the signals")
plt.show()

# %%
values, counts = np.unique(y_windows_validation, return_counts=True)

plt.figure(figsize=(12,6))
plt.bar(values, counts, color='lightcoral', edgecolor='black', width=0.1)
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Barplot of value frequencies of the scaled values of the gestational age in the validation set after windowing of the signals")
plt.show()

# %%
values, counts = np.unique(y_windows_test, return_counts=True)

plt.figure(figsize=(12,6))
plt.bar(values, counts, color='lightcoral', edgecolor='black', width=0.1)
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Barplot of value frequencies of the scaled values of the gestational age in the testing set after windowing of the signals")
plt.show()

# %%
values, counts = np.unique(y_windows_test_sick, return_counts=True)

plt.figure(figsize=(12,6))
plt.bar(values, counts, color='lightcoral', edgecolor='black', width=0.1)
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Barplot of value frequencies of the scaled values of the gestational age in the set of fetuses affected by IUGR after windowing of the signals")
plt.show()

# %% [markdown]
# # Model

# %% [markdown]
# The model is a ResNet with SE attention blocks

# %%
X_train = np.stack([X_windows_train, X_windows_train_qa], axis=-1)  # (batch_size, timesteps, 2)
X_val = np.stack([X_windows_validation, X_windows_validation_qa], axis=-1)  # (batch_size, timesteps, 2)
X_test = np.stack([X_windows_test, X_windows_test_qa], axis=-1)  # (batch_size, timesteps, 2)
X_test_sick = np.stack([X_windows_test_sick, X_windows_test_sick_qa], axis=-1)  # (batch_size, timesteps, 2)

# %%
import tensorflow as tf
class RandomLinearInterpolationNoise(tf.keras.layers.Layer):
    def __init__(self, Interp_probability=0.1, Max_inter_len=3*2*60, **kwargs):
        super(RandomLinearInterpolationNoise, self).__init__(**kwargs)
        self.Interp_probability = Interp_probability
        self.Max_inter_len = Max_inter_len

    def call(self, inputs, training=None):
        if not training:
            return inputs
        else:
            if tf.random.uniform(shape=[1], minval=0., maxval=1.) < self.Interp_probability:
                shape = tf.shape(inputs)
                batch_size, num_points, num_channels = shape[0], shape[1], shape[2]
                
                inter_len = tf.random.uniform([], minval=1, maxval=self.Max_inter_len, dtype=tf.int32)
                MaxVal = num_points - inter_len
                start_point = tf.random.uniform([], minval=1, maxval=MaxVal, dtype=tf.int32)
                end_point = start_point + inter_len

                mask = tf.concat([
                    tf.zeros((batch_size, start_point, num_channels), dtype=tf.float32),
                    tf.ones((batch_size, inter_len, num_channels), dtype=tf.float32),
                    tf.zeros((batch_size, num_points - end_point, num_channels), dtype=tf.float32)
                ], axis=1)

                linearly_spaced_values_t = tf.linspace(inputs[:, start_point, :], inputs[:, end_point, :], inter_len, axis=1)
                linearly_spaced_values = tf.concat([
                    tf.zeros((batch_size, start_point, num_channels), dtype=tf.float32),
                    linearly_spaced_values_t,
                    tf.zeros((batch_size, num_points - end_point, num_channels), dtype=tf.float32)
                ], axis=1)

                return inputs * (1 - mask) + mask * linearly_spaced_values
            else:
                return inputs


from tensorflow import keras

def se_block(input_tensor, reduction):
    filters = input_tensor.shape[-1]  
    se = keras.layers.GlobalAveragePooling1D()(input_tensor)  # Squeeze
    se = keras.layers.Dense(filters // reduction, activation='relu')(se)  # Bottleneck
    se = keras.layers.Dense(filters, activation='sigmoid')(se)  # Scaling
    se = keras.layers.Multiply()([input_tensor, keras.layers.Reshape((1, filters))(se)])  # Recalibration
    return se

#resnet
def build_model(input_shape, classes, drop_out_rate, Interp_probability=0.05, Max_inter_len=3*2*60, n_feature_maps = 32):
        
        input_layer = keras.layers.Input(input_shape)
        input_layer = keras.layers.GaussianNoise(0.05)(input_layer) #add Gaussian Noise
        input_layer = RandomLinearInterpolationNoise(Interp_probability=Interp_probability, Max_inter_len=Max_inter_len)(input_layer)
        # BLOCK 1

        conv_x = keras.layers.Conv1D(filters=n_feature_maps, kernel_size=8, padding='same')(input_layer)
        conv_x = keras.layers.BatchNormalization()(conv_x)
        conv_x = keras.layers.Activation('relu')(conv_x)

        conv_y = keras.layers.Conv1D(filters=n_feature_maps, kernel_size=5, padding='same')(conv_x)
        conv_y = keras.layers.BatchNormalization()(conv_y)
        conv_y = keras.layers.Activation('relu')(conv_y)

        conv_z = keras.layers.Conv1D(filters=n_feature_maps, kernel_size=3, padding='same')(conv_y)
        conv_z = keras.layers.BatchNormalization()(conv_z)

        # expand channels for the sum
        shortcut_y = keras.layers.Conv1D(filters=n_feature_maps, kernel_size=1, padding='same')(input_layer)
        shortcut_y = keras.layers.BatchNormalization()(shortcut_y)

        output_block_1 = keras.layers.add([shortcut_y, conv_z])
        output_block_1 = se_block(output_block_1, reduction=2*8)
        output_block_1 = keras.layers.Dropout(drop_out_rate)(output_block_1) #
        output_block_1 = keras.layers.Activation('relu')(output_block_1)

        # BLOCK 2

        conv_x = keras.layers.Conv1D(filters=n_feature_maps * 2, kernel_size=8, padding='same')(output_block_1)
        conv_x = keras.layers.BatchNormalization()(conv_x)
        conv_x = keras.layers.Activation('relu')(conv_x)

        conv_y = keras.layers.Conv1D(filters=n_feature_maps * 2, kernel_size=5, padding='same')(conv_x)
        conv_y = keras.layers.BatchNormalization()(conv_y)
        conv_y = keras.layers.Activation('relu')(conv_y)

        conv_z = keras.layers.Conv1D(filters=n_feature_maps * 2, kernel_size=3, padding='same')(conv_y)
        conv_z = keras.layers.BatchNormalization()(conv_z)

        # expand channels for the sum
        shortcut_y = keras.layers.Conv1D(filters=n_feature_maps * 2, kernel_size=1, padding='same')(output_block_1)
        shortcut_y = keras.layers.BatchNormalization()(shortcut_y)

        output_block_2 = keras.layers.add([shortcut_y, conv_z])
        output_block_2 = se_block(output_block_2, reduction=3*8)
        output_block_2 = keras.layers.Dropout(drop_out_rate)(output_block_2) #
        output_block_2 = keras.layers.Activation('relu')(output_block_2)

        # BLOCK 3

        conv_x = keras.layers.Conv1D(filters=n_feature_maps * 2, kernel_size=8, padding='same')(output_block_2)
        conv_x = keras.layers.BatchNormalization()(conv_x)
        conv_x = keras.layers.Activation('relu')(conv_x)

        conv_y = keras.layers.Conv1D(filters=n_feature_maps * 2, kernel_size=5, padding='same')(conv_x)
        conv_y = keras.layers.BatchNormalization()(conv_y)
        conv_y = keras.layers.Activation('relu')(conv_y)

        conv_z = keras.layers.Conv1D(filters=n_feature_maps * 2, kernel_size=3, padding='same')(conv_y)
        conv_z = keras.layers.BatchNormalization()(conv_z)

        # no need to expand channels because they are equal
        shortcut_y = keras.layers.BatchNormalization()(output_block_2)

        output_block_3 = keras.layers.add([shortcut_y, conv_z])
        output_block_3 = se_block(output_block_3, reduction=4*8)
        output_block_3 = keras.layers.Dropout(drop_out_rate)(output_block_3) #
        output_block_3 = keras.layers.Activation('relu')(output_block_3)

        # FINAL

        gap_layer = keras.layers.GlobalAveragePooling1D()(output_block_3)
        gap_layer = keras.layers.Dropout(drop_out_rate)(gap_layer) # To avoid overfitting
        output_layer = keras.layers.Dense(classes, activation='linear')(gap_layer)

        model = keras.models.Model(inputs=input_layer, outputs=output_layer)

        return model

# %%
X_windows_train.shape
# Out:
# (27659, 3600)

# %%
X_windows_train[0]
# Out:
# array([-0.8528068545596585, -1.059697163453328, -1.3552547475871417, ...,
#        -1.3256989891737603, -1.2665874723469976, -1.059697163453328],
#       dtype=object)

# %% [markdown]
# # Training

# %%
X_windows_train = tf.convert_to_tensor(X_train, dtype=tf.float32)
X_windows_validation = tf.convert_to_tensor(X_val, dtype=tf.float32)
X_windows_test = tf.convert_to_tensor(X_test, dtype=tf.float32)
X_windows_test_sick = tf.convert_to_tensor(X_test_sick, dtype=tf.float32)

# %%
model = build_model(input_shape=(X_windows_train.shape[1], X_windows_train.shape[2]), classes=1, drop_out_rate=0.2, Interp_probability=0.05, Max_inter_len=3*2*60, n_feature_maps = 32)

# %%
y_windows_train = tf.convert_to_tensor(y_windows_train, dtype=tf.float32)
y_windows_validation = tf.convert_to_tensor(y_windows_validation, dtype=tf.float32)
y_windows_test = tf.convert_to_tensor(y_windows_test, dtype=tf.float32)
y_windows_test_sick = tf.convert_to_tensor(y_windows_test_sick, dtype=tf.float32)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 3600, 2)]    0           []
#
#  conv1d (Conv1D)                (None, 3600, 32)     544         ['input_2[0][0]']
#
#  batch_normalization (BatchNorm  (None, 3600, 32)    128         ['conv1d[1][0]']
#  alization)
#
#  activation (Activation)        (None, 3600, 32)     0           ['batch_normalization[1][0]']
#
#  conv1d_1 (Conv1D)              (None, 3600, 32)     5152        ['activation[1][0]']
#
#  batch_normalization_1 (BatchNo  (None, 3600, 32)    128         ['conv1d_1[1][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 3600, 32)     0           ['batch_normalization_1[1][0]']
#
#  conv1d_3 (Conv1D)              (None, 3600, 32)     96          ['input_2[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 3600, 32)     3104        ['activation_1[1][0]']
#
#  batch_normalization_3 (BatchNo  (None, 3600, 32)    128         ['conv1d_3[1][0]']
#  rmalization)
#
#  batch_normalization_2 (BatchNo  (None, 3600, 32)    128         ['conv1d_2[1][0]']
#  rmalization)
#
#  add (Add)                      (None, 3600, 32)     0           ['batch_normalization_3[1][0]',
#                                                                   'batch_normalization_2[1][0]']
#
#  global_average_pooling1d (Glob  (None, 32)          0           ['add[1][0]']
#  alAveragePooling1D)
#
#  dense (Dense)                  (None, 2)            66          ['global_average_pooling1d[1][0]'
#                                                                  ]
#
#  dense_1 (Dense)                (None, 32)           96          ['dense[1][0]']
#
#  reshape (Reshape)              (None, 1, 32)        0           ['dense_1[1][0]']
#
#  multiply (Multiply)            (None, 3600, 32)     0           ['add[1][0]',
#                                                                   'reshape[1][0]']
#
#  dropout (Dropout)              (None, 3600, 32)     0           ['multiply[1][0]']
#
#  activation_2 (Activation)      (None, 3600, 32)     0           ['dropout[1][0]']
#
#  conv1d_4 (Conv1D)              (None, 3600, 64)     16448       ['activation_2[1][0]']
#
#  batch_normalization_4 (BatchNo  (None, 3600, 64)    256         ['conv1d_4[1][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 3600, 64)     0           ['batch_normalization_4[1][0]']
#
#  conv1d_5 (Conv1D)              (None, 3600, 64)     20544       ['activation_3[1][0]']
#
#  batch_normalization_5 (BatchNo  (None, 3600, 64)    256         ['conv1d_5[1][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 3600, 64)     0           ['batch_normalization_5[1][0]']
#
#  conv1d_7 (Conv1D)              (None, 3600, 64)     2112        ['activation_2[1][0]']
#
#  conv1d_6 (Conv1D)              (None, 3600, 64)     12352       ['activation_4[1][0]']
#
#  batch_normalization_7 (BatchNo  (None, 3600, 64)    256         ['conv1d_7[1][0]']
#  rmalization)
#
#  batch_normalization_6 (BatchNo  (None, 3600, 64)    256         ['conv1d_6[1][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 3600, 64)     0           ['batch_normalization_7[1][0]',
#                                                                   'batch_normalization_6[1][0]']
#
#  global_average_pooling1d_1 (Gl  (None, 64)          0           ['add_1[1][0]']
#  obalAveragePooling1D)
#
#  dense_2 (Dense)                (None, 2)            130         ['global_average_pooling1d_1[1][0
#                                                                  ]']
#
#  dense_3 (Dense)                (None, 64)           192         ['dense_2[1][0]']
#
#  reshape_1 (Reshape)            (None, 1, 64)        0           ['dense_3[1][0]']
#
#  multiply_1 (Multiply)          (None, 3600, 64)     0           ['add_1[1][0]',
#                                                                   'reshape_1[1][0]']
#
#  dropout_1 (Dropout)            (None, 3600, 64)     0           ['multiply_1[1][0]']
#
#  activation_5 (Activation)      (None, 3600, 64)     0           ['dropout_1[1][0]']
#
#  conv1d_8 (Conv1D)              (None, 3600, 64)     32832       ['activation_5[1][0]']
#
#  batch_normalization_8 (BatchNo  (None, 3600, 64)    256         ['conv1d_8[1][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 3600, 64)     0           ['batch_normalization_8[1][0]']
#
#  conv1d_9 (Conv1D)              (None, 3600, 64)     20544       ['activation_6[1][0]']
#
#  batch_normalization_9 (BatchNo  (None, 3600, 64)    256         ['conv1d_9[1][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 3600, 64)     0           ['batch_normalization_9[1][0]']
#
#  conv1d_10 (Conv1D)             (None, 3600, 64)     12352       ['activation_7[1][0]']
#
#  batch_normalization_11 (BatchN  (None, 3600, 64)    256         ['activation_5[1][0]']
#  ormalization)
#
#  batch_normalization_10 (BatchN  (None, 3600, 64)    256         ['conv1d_10[1][0]']
#  ormalization)
#
#  add_2 (Add)                    (None, 3600, 64)     0           ['batch_normalization_11[1][0]',
#                                                                   'batch_normalization_10[1][0]']
#
#  global_average_pooling1d_2 (Gl  (None, 64)          0           ['add_2[1][0]']
#  obalAveragePooling1D)
#
#  dense_4 (Dense)                (None, 2)            130         ['global_average_pooling1d_2[1][0
#                                                                  ]']
#
#  dense_5 (Dense)                (None, 64)           192         ['dense_4[1][0]']
#
#  reshape_2 (Reshape)            (None, 1, 64)        0           ['dense_5[1][0]']
#
#  multiply_2 (Multiply)          (None, 3600, 64)     0           ['add_2[1][0]',
#                                                                   'reshape_2[1][0]']
#
#  dropout_2 (Dropout)            (None, 3600, 64)     0           ['multiply_2[1][0]']
#
#  activation_8 (Activation)      (None, 3600, 64)     0           ['dropout_2[1][0]']
#
#  global_average_pooling1d_3 (Gl  (None, 64)          0           ['activation_8[1][0]']
#  obalAveragePooling1D)
#
#  dropout_3 (Dropout)            (None, 64)           0           ['global_average_pooling1d_3[1][0
#                                                                  ]']
#
#  dense_6 (Dense)                (None, 1)            65          ['dropout_3[1][0]']
#
# ==================================================================================================
# Total params: 129,511
# Trainable params: 128,231
# Non-trainable params: 1,280
# __________________________________________________________________________________________________

# %%
X_windows_train.shape
# Out:
# TensorShape([27659, 3600, 2])

# %%
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ReduceLROnPlateau
import keras.backend as K
import gc
history = {}

reduce_lr = ReduceLROnPlateau(monitor='val_loss',  
                              factor=0.5,         
                              patience=10,          
                              min_lr=1e-6,         
                              verbose=1)     




model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0006103052350290162),
    loss='mse', 
    metrics=['mae']
)
early_stopping = EarlyStopping(
    monitor='val_loss',       
    patience=15,              
    restore_best_weights=True,
    mode='min'  
)
new_history = model.fit(X_windows_train, y_windows_train, epochs=200, batch_size=32, validation_data=(X_windows_validation, y_windows_validation),  callbacks=[early_stopping, reduce_lr]).history
history.update({k: history.get(k, []) + new_history.get(k, []) for k in set(history) | set(new_history)})
# Out:
# Epoch 1/200
# 865/865 [==============================] - 179s 196ms/step - loss: 0.1363 - mae: 0.2922 - val_loss: 0.1389 - val_mae: 0.2937 - lr: 6.1031e-04
# Epoch 2/200
# 865/865 [==============================] - 168s 194ms/step - loss: 0.1266 - mae: 0.2820 - val_loss: 0.1380 - val_mae: 0.2956 - lr: 6.1031e-04
# Epoch 3/200
# 865/865 [==============================] - 168s 195ms/step - loss: 0.1240 - mae: 0.2786 - val_loss: 0.1320 - val_mae: 0.2845 - lr: 6.1031e-04
# Epoch 4/200
# 865/865 [==============================] - 168s 194ms/step - loss: 0.1205 - mae: 0.2747 - val_loss: 0.1295 - val_mae: 0.2843 - lr: 6.1031e-04
# Epoch 5/200
# 865/865 [==============================] - 165s 191ms/step - loss: 0.1173 - mae: 0.2708 - val_loss: 0.1324 - val_mae: 0.2822 - lr: 6.1031e-04
# Epoch 6/200
# 865/865 [==============================] - 165s 191ms/step - loss: 0.1143 - mae: 0.2671 - val_loss: 0.1227 - val_mae: 0.2731 - lr: 6.1031e-04
# Epoch 7/200
# 865/865 [==============================] - 165s 191ms/step - loss: 0.1118 - mae: 0.2641 - val_loss: 0.1320 - val_mae: 0.2834 - lr: 6.1031e-04
# Epoch 8/200
# 865/865 [==============================] - 166s 192ms/step - loss: 0.1105 - mae: 0.2629 - val_loss: 0.1211 - val_mae: 0.2754 - lr: 6.1031e-04
# Epoch 9/200
# 865/865 [==============================] - 166s 192ms/step - loss: 0.1094 - mae: 0.2613 - val_loss: 0.1198 - val_mae: 0.2737 - lr: 6.1031e-04
# Epoch 10/200
# 865/865 [==============================] - 165s 191ms/step - loss: 0.1085 - mae: 0.2600 - val_loss: 0.1203 - val_mae: 0.2709 - lr: 6.1031e-04
# Epoch 11/200
# 865/865 [==============================] - 165s 191ms/step - loss: 0.1076 - mae: 0.2589 - val_loss: 0.1187 - val_mae: 0.2719 - lr: 6.1031e-04
# Epoch 12/200
# 865/865 [==============================] - 167s 193ms/step - loss: 0.1076 - mae: 0.2588 - val_loss: 0.1166 - val_mae: 0.2677 - lr: 6.1031e-04
# Epoch 13/200
# 865/865 [==============================] - 167s 193ms/step - loss: 0.1066 - mae: 0.2579 - val_loss: 0.1194 - val_mae: 0.2748 - lr: 6.1031e-04
# Epoch 14/200
# 865/865 [==============================] - 167s 193ms/step - loss: 0.1061 - mae: 0.2573 - val_loss: 0.1288 - val_mae: 0.2790 - lr: 6.1031e-04
# Epoch 15/200
# 865/865 [==============================] - 167s 193ms/step - loss: 0.1054 - mae: 0.2559 - val_loss: 0.1184 - val_mae: 0.2694 - lr: 6.1031e-04
# Epoch 16/200
# 865/865 [==============================] - 167s 193ms/step - loss: 0.1053 - mae: 0.2561 - val_loss: 0.1254 - val_mae: 0.2824 - lr: 6.1031e-04
# Epoch 17/200
# 865/865 [==============================] - 167s 193ms/step - loss: 0.1042 - mae: 0.2545 - val_loss: 0.1227 - val_mae: 0.2802 - lr: 6.1031e-04
# Epoch 18/200
# 865/865 [==============================] - 167s 193ms/step - loss: 0.1043 - mae: 0.2545 - val_loss: 0.1163 - val_mae: 0.2681 - lr: 6.1031e-04
# Epoch 19/200
# 865/865 [==============================] - 166s 192ms/step - loss: 0.1034 - mae: 0.2539 - val_loss: 0.1257 - val_mae: 0.2853 - lr: 6.1031e-04
# Epoch 20/200
# 865/865 [==============================] - 167s 193ms/step - loss: 0.1031 - mae: 0.2529 - val_loss: 0.1148 - val_mae: 0.2659 - lr: 6.1031e-04
# Epoch 21/200
# 865/865 [==============================] - 167s 193ms/step - loss: 0.1026 - mae: 0.2523 - val_loss: 0.1209 - val_mae: 0.2777 - lr: 6.1031e-04
# Epoch 22/200
# 865/865 [==============================] - 167s 193ms/step - loss: 0.1025 - mae: 0.2526 - val_loss: 0.1183 - val_mae: 0.2690 - lr: 6.1031e-04
# Epoch 23/200
# 865/865 [==============================] - 167s 193ms/step - loss: 0.1020 - mae: 0.2516 - val_loss: 0.1166 - val_mae: 0.2674 - lr: 6.1031e-04
# Epoch 24/200
# 865/865 [==============================] - 167s 193ms/step - loss: 0.1014 - mae: 0.2511 - val_loss: 0.1119 - val_mae: 0.2648 - lr: 6.1031e-04
# Epoch 25/200
# 865/865 [==============================] - 166s 192ms/step - loss: 0.1013 - mae: 0.2507 - val_loss: 0.1451 - val_mae: 0.2960 - lr: 6.1031e-04
# Epoch 26/200
# 865/865 [==============================] - 166s 192ms/step - loss: 0.1012 - mae: 0.2505 - val_loss: 0.1140 - val_mae: 0.2637 - lr: 6.1031e-04
# Epoch 27/200
# 865/865 [==============================] - 167s 193ms/step - loss: 0.1009 - mae: 0.2505 - val_loss: 0.1108 - val_mae: 0.2629 - lr: 6.1031e-04
# Epoch 28/200
# 865/865 [==============================] - 167s 193ms/step - loss: 0.1001 - mae: 0.2491 - val_loss: 0.1156 - val_mae: 0.2669 - lr: 6.1031e-04
# Epoch 29/200
# 865/865 [==============================] - 166s 192ms/step - loss: 0.0999 - mae: 0.2494 - val_loss: 0.1110 - val_mae: 0.2627 - lr: 6.1031e-04
# Epoch 30/200
# 865/865 [==============================] - 166s 192ms/step - loss: 0.0996 - mae: 0.2489 - val_loss: 0.1313 - val_mae: 0.2831 - lr: 6.1031e-04
# Epoch 31/200
# 865/865 [==============================] - 166s 192ms/step - loss: 0.0992 - mae: 0.2481 - val_loss: 0.1125 - val_mae: 0.2635 - lr: 6.1031e-04
# Epoch 32/200
# 865/865 [==============================] - 167s 193ms/step - loss: 0.0991 - mae: 0.2479 - val_loss: 0.1183 - val_mae: 0.2753 - lr: 6.1031e-04
# Epoch 33/200
# 865/865 [==============================] - 167s 193ms/step - loss: 0.0986 - mae: 0.2472 - val_loss: 0.1258 - val_mae: 0.2759 - lr: 6.1031e-04
# Epoch 34/200
# 865/865 [==============================] - 167s 193ms/step - loss: 0.0984 - mae: 0.2471 - val_loss: 0.1218 - val_mae: 0.2794 - lr: 6.1031e-04
# Epoch 35/200
# 865/865 [==============================] - 167s 193ms/step - loss: 0.0981 - mae: 0.2464 - val_loss: 0.1147 - val_mae: 0.2661 - lr: 6.1031e-04
# Epoch 36/200
# 865/865 [==============================] - 166s 192ms/step - loss: 0.0981 - mae: 0.2465 - val_loss: 0.1240 - val_mae: 0.2802 - lr: 6.1031e-04
# Epoch 37/200
# 865/865 [==============================] - ETA: 0s - loss: 0.0980 - mae: 0.2466
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.00030515261460095644.
# 865/865 [==============================] - 167s 193ms/step - loss: 0.0980 - mae: 0.2466 - val_loss: 0.1116 - val_mae: 0.2630 - lr: 6.1031e-04
# Epoch 38/200
# 865/865 [==============================] - 167s 192ms/step - loss: 0.0955 - mae: 0.2428 - val_loss: 0.1175 - val_mae: 0.2741 - lr: 3.0515e-04
# Epoch 39/200
# 865/865 [==============================] - 167s 192ms/step - loss: 0.0948 - mae: 0.2428 - val_loss: 0.1115 - val_mae: 0.2639 - lr: 3.0515e-04
# Epoch 40/200
# 865/865 [==============================] - 166s 192ms/step - loss: 0.0943 - mae: 0.2416 - val_loss: 0.1123 - val_mae: 0.2614 - lr: 3.0515e-04
# Epoch 41/200
# 865/865 [==============================] - 166s 192ms/step - loss: 0.0942 - mae: 0.2413 - val_loss: 0.1196 - val_mae: 0.2741 - lr: 3.0515e-04
# Epoch 42/200
# 865/865 [==============================] - 167s 193ms/step - loss: 0.0935 - mae: 0.2405 - val_loss: 0.1107 - val_mae: 0.2637 - lr: 3.0515e-04
# Epoch 43/200
# 865/865 [==============================] - 166s 192ms/step - loss: 0.0935 - mae: 0.2403 - val_loss: 0.1128 - val_mae: 0.2626 - lr: 3.0515e-04
# Epoch 44/200
# 865/865 [==============================] - 166s 192ms/step - loss: 0.0937 - mae: 0.2409 - val_loss: 0.1094 - val_mae: 0.2612 - lr: 3.0515e-04
# Epoch 45/200
# 865/865 [==============================] - 167s 193ms/step - loss: 0.0933 - mae: 0.2404 - val_loss: 0.1199 - val_mae: 0.2747 - lr: 3.0515e-04
# Epoch 46/200
# 865/865 [==============================] - 167s 193ms/step - loss: 0.0928 - mae: 0.2402 - val_loss: 0.1253 - val_mae: 0.2827 - lr: 3.0515e-04
# Epoch 47/200
# 865/865 [==============================] - 167s 193ms/step - loss: 0.0925 - mae: 0.2392 - val_loss: 0.1096 - val_mae: 0.2603 - lr: 3.0515e-04
# Epoch 48/200
# 865/865 [==============================] - 167s 193ms/step - loss: 0.0923 - mae: 0.2390 - val_loss: 0.1130 - val_mae: 0.2651 - lr: 3.0515e-04
# Epoch 49/200
# 865/865 [==============================] - 167s 193ms/step - loss: 0.0923 - mae: 0.2390 - val_loss: 0.1119 - val_mae: 0.2639 - lr: 3.0515e-04
# Epoch 50/200
# 865/865 [==============================] - 167s 193ms/step - loss: 0.0919 - mae: 0.2387 - val_loss: 0.1110 - val_mae: 0.2624 - lr: 3.0515e-04
# Epoch 51/200
# 865/865 [==============================] - 167s 193ms/step - loss: 0.0917 - mae: 0.2386 - val_loss: 0.1111 - val_mae: 0.2619 - lr: 3.0515e-04
# Epoch 52/200
# 865/865 [==============================] - 167s 193ms/step - loss: 0.0918 - mae: 0.2384 - val_loss: 0.1132 - val_mae: 0.2660 - lr: 3.0515e-04
# Epoch 53/200
# 865/865 [==============================] - 167s 193ms/step - loss: 0.0913 - mae: 0.2378 - val_loss: 0.1252 - val_mae: 0.2795 - lr: 3.0515e-04
# Epoch 54/200
# 865/865 [==============================] - ETA: 0s - loss: 0.0911 - mae: 0.2374
# Epoch 54: ReduceLROnPlateau reducing learning rate to 0.00015257630730047822.
# 865/865 [==============================] - 167s 193ms/step - loss: 0.0911 - mae: 0.2374 - val_loss: 0.1125 - val_mae: 0.2629 - lr: 3.0515e-04
# Epoch 55/200
# 865/865 [==============================] - 167s 193ms/step - loss: 0.0897 - mae: 0.2356 - val_loss: 0.1105 - val_mae: 0.2609 - lr: 1.5258e-04
# Epoch 56/200
# 865/865 [==============================] - 167s 193ms/step - loss: 0.0886 - mae: 0.2345 - val_loss: 0.1134 - val_mae: 0.2645 - lr: 1.5258e-04
# Epoch 57/200
# 865/865 [==============================] - 167s 193ms/step - loss: 0.0889 - mae: 0.2346 - val_loss: 0.1179 - val_mae: 0.2721 - lr: 1.5258e-04
# Epoch 58/200
# 865/865 [==============================] - 167s 193ms/step - loss: 0.0885 - mae: 0.2342 - val_loss: 0.1137 - val_mae: 0.2644 - lr: 1.5258e-04
# Epoch 59/200
# 865/865 [==============================] - 167s 193ms/step - loss: 0.0880 - mae: 0.2333 - val_loss: 0.1157 - val_mae: 0.2681 - lr: 1.5258e-04

# %%
model.save("model_with_QA_mean.keras")

# %% [markdown]
# # Results

# %%
start = 0
plt.plot(history['loss'][start:], label='Training loss')
plt.plot(history['val_loss'][start:], label='Validation loss')
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('Epoch')
plt.legend(loc='lower right')
plt.show()

# %%
start = 0
plt.plot(history['mae'][start:], label='Training MAE')
plt.plot(history['val_mae'][start:], label='Validation MAE')
plt.title('Model MAE')
plt.ylabel('MAE')
plt.xlabel('Epoch')
plt.legend(loc='lower right')
plt.show()

# %%
import seaborn as sns
from sklearn.metrics import mean_squared_error, mean_absolute_error

y_true = []
y_pred = []

predictions = model.predict(X_windows_test)
true_labels = y_windows_test
y_true.extend(true_labels)
y_pred.extend(predictions)

mse = mean_squared_error(true_labels, predictions)
mae = mean_absolute_error(true_labels, predictions)

print(f"Mean Squared Error (MSE): {mse}")
print(f"Mean Absolute Error (MAE): {mae}")

y_true_sick = []
y_pred_sick = []

predictions_sick = model.predict(X_windows_test_sick)
true_labels_sick = y_windows_test_sick
y_true_sick.extend(true_labels_sick)
y_pred_sick.extend(predictions_sick)

mse_sick = mean_squared_error(true_labels_sick, predictions_sick)
mae_sick = mean_absolute_error(true_labels_sick, predictions_sick)

print(f"Mean Squared Error (MSE) for sick: {mse_sick}")
print(f"Mean Absolute Error (MAE) for sick: {mae_sick}")

plt.figure(figsize=(8, 8))
plt.scatter(true_labels, predictions, color='blue')
min_val = min(min(true_labels_sick), min(predictions_sick))
max_val = max(max(true_labels), max(predictions))
plt.scatter(true_labels_sick, predictions_sick, color='orange')
plt.plot([min_val, max_val], [min_val, max_val], color='red', linestyle='--')
plt.xlim(min_val, max_val)
plt.xlabel("True Values")
plt.ylabel("Predictions")
plt.title("Predictions vs. True Values")
plt.show()
# Out:
# 110/110 [==============================] - 5s 46ms/step
# Mean Squared Error (MSE): 0.10551460087299347
# Mean Absolute Error (MAE): 0.2570282518863678
# 120/120 [==============================] - 6s 47ms/step
# Mean Squared Error (MSE) for sick: 0.4664350152015686
# Mean Absolute Error (MAE) for sick: 0.5164083242416382

# %% [markdown]
# Consider the predictions between the 5th and the 95th percentile and compute again the metrics

# %%
lower = np.percentile(y_true, 5)
upper = np.percentile(y_true, 95)
print(lower)
print(upper)

mask = (y_true >= lower) & (y_true <= upper)
mask_sick = (y_true_sick >= lower) & (y_true_sick <= upper)

filtered_y_true = np.array(y_true)[mask]
filtered_y_pred = np.array(y_pred)[mask]
filtered_y_true_sick = np.array(y_true_sick)[mask_sick]
filtered_y_pred_sick = np.array(y_pred_sick)[mask_sick]

mse = mean_squared_error(filtered_y_true, filtered_y_pred)
mae = mean_absolute_error(filtered_y_true, filtered_y_pred)

print(f"Mean Squared Error (MSE): {mse}")
print(f"Mean Absolute Error (MAE): {mae}")

mse_sick = mean_squared_error(filtered_y_true_sick, filtered_y_pred_sick)
mae_sick = mean_absolute_error(filtered_y_true_sick, filtered_y_pred_sick)

print(f"Mean Squared Error (MSE) for sick: {mse_sick}")
print(f"Mean Absolute Error (MAE) for sick: {mae_sick}")

plt.figure(figsize=(8, 8))
plt.scatter(filtered_y_true, filtered_y_pred, color='blue', label='Healthy')
plt.scatter(filtered_y_true_sick, filtered_y_pred_sick, color='orange', label='Sick')
min_val = min(min(filtered_y_true_sick), min(filtered_y_pred_sick))
max_val = max(max(filtered_y_true), max(filtered_y_pred))
plt.plot([min_val, max_val], [min_val, max_val], color='red', linestyle='--')
plt.xlim(min_val, max_val)
plt.xlabel("True Values")
plt.ylabel("Predictions")
plt.title("Filtered Predictions vs. True Values")
plt.legend()
plt.show()
# Out:
# -0.7142857313156128
# 0.5873016119003296
# Mean Squared Error (MSE): 0.07705468684434891
# Mean Absolute Error (MAE): 0.22317653894424438
# Mean Squared Error (MSE) for sick: 0.09984338283538818
# Mean Absolute Error (MAE) for sick: 0.2578203082084656

# %% [markdown]
# This is for the Days, so not scaled

# %%
predictions_giorni = scaler.inverse_transform(predictions)
true_labels_giorni = scaler.inverse_transform(true_labels)

mse_giorni = mean_squared_error(true_labels_giorni, predictions_giorni)
mae_giorni = mean_absolute_error(true_labels_giorni, predictions_giorni)
print(f"Mean Squared Error (MSE): {mse_giorni}")
print(f"Mean Absolute Error (MAE): {mae_giorni}")

predictions_giorni_sick = scaler.inverse_transform(predictions_sick)
true_labels_giorni_sick = scaler.inverse_transform(true_labels_sick)

mse_giorni_sick = mean_squared_error(true_labels_giorni_sick, predictions_giorni_sick)
mae_giorni_sick = mean_absolute_error(true_labels_giorni_sick, predictions_giorni_sick)
print(f"Mean Squared Error (MSE): {mse_giorni_sick}")
print(f"Mean Absolute Error (MAE): {mae_giorni_sick}")

plt.figure(figsize=(8, 8))
plt.scatter(true_labels_giorni, predictions_giorni, color='blue')
plt.scatter(true_labels_giorni_sick, predictions_giorni_sick, color='orange')
min_val = min(min(true_labels_giorni_sick), min(predictions_giorni_sick))
max_val = max(max(true_labels_giorni), max(predictions_giorni))
plt.xlim([min_val, max_val])
plt.ylim([min_val, max_val])
plt.plot([min_val, max_val], [min_val, max_val], color='red', linestyle='--')
plt.xlabel("True Labels")
plt.ylabel("Predictions")
plt.title("True Labels vs Predictions")
plt.grid()
plt.show()
# Out:
# Mean Squared Error (MSE): 104.6968578884979
# Mean Absolute Error (MAE): 8.096390302655324
# Mean Squared Error (MSE): 462.8201208848533
# Mean Absolute Error (MAE): 16.26686201188399

# %%
lower = np.percentile(true_labels_giorni, 5)
upper = np.percentile(true_labels_giorni, 95)
print(lower)
print(upper)

mask = (true_labels_giorni >= lower) & (true_labels_giorni <= upper)
mask_sick = (true_labels_giorni_sick >= lower) & (true_labels_giorni_sick <= upper)

filtered_y_true_giorni = np.array(true_labels_giorni)[mask]
filtered_y_pred_giorni = np.array(predictions_giorni)[mask]
filtered_y_true_sick = np.array(true_labels_giorni_sick)[mask_sick]
filtered_y_pred_sick = np.array(predictions_giorni_sick)[mask_sick]

mse = mean_squared_error(filtered_y_true_giorni, filtered_y_pred_giorni)
mae = mean_absolute_error(filtered_y_true_giorni, filtered_y_pred_giorni)

print(f"Mean Squared Error (MSE): {mse}")
print(f"Mean Absolute Error (MAE): {mae}")

mse_sick = mean_squared_error(filtered_y_true_sick, filtered_y_pred_sick)
mae_sick = mean_absolute_error(filtered_y_true_sick, filtered_y_pred_sick)

print(f"Mean Squared Error (MSE) for sick: {mse_sick}")
print(f"Mean Absolute Error (MAE) for sick: {mae_sick}")

plt.figure(figsize=(8, 8))
plt.scatter(filtered_y_true_giorni, filtered_y_pred_giorni, color='blue', label='Healthy')
plt.scatter(filtered_y_true_sick, filtered_y_pred_sick, color='orange', label='Sick')
min_val = min(min(filtered_y_true_sick), min(filtered_y_pred_sick))
max_val = max(max(filtered_y_true_giorni), max(filtered_y_pred_giorni))
plt.plot([min_val, max_val], [min_val, max_val], color='red', linestyle='--')
plt.xlim(min_val, max_val)
plt.xlabel("True Values")
plt.ylabel("Predictions")
plt.title("Filtered Predictions vs. True Values")
plt.legend()
plt.show()
# Out:
# 238.99999946355817
# 280.0000007748604
# Mean Squared Error (MSE): 76.45751034643939
# Mean Absolute Error (MAE): 7.030060867856283
# Mean Squared Error (MSE) for sick: 99.06959898849301
# Mean Absolute Error (MAE) for sick: 8.121338974554106

# %%
from sklearn.metrics import r2_score
r2 = r2_score(true_labels, predictions)
print(f"R-squared: {r2}")


r2_sick = r2_score(true_labels_sick, predictions_sick)
print(f"R-squared for sick: {r2_sick}")
# Out:
# R-squared: 0.2634762780154817
# R-squared for sick: 0.18770441946998684

# %%
r2_filtered = r2_score(filtered_y_true, filtered_y_pred)
print(f"R-squared for filtered: {r2_filtered}")
r2_filtered_sick = r2_score(filtered_y_true_sick, filtered_y_pred_sick)
print(f"R-squared for filtered sick: {r2_filtered_sick}")
# Out:
# R-squared for filtered: 0.2177165665410613
# R-squared for filtered sick: 0.22459700580612751

# %%
from scipy.stats import pearsonr
corr, _ = pearsonr(true_labels.numpy().flatten(), predictions.flatten())
print(f"Pearson correlation coefficient: {corr}")
corrsick, _ = pearsonr(true_labels_sick.numpy().flatten(), predictions_sick.flatten())
print(f"Pearson correlation coefficient: {corrsick}")
# Out:
# Pearson correlation coefficient: 0.5194863931394285
# Pearson correlation coefficient: 0.663050577746204

# %%
corr_filtered, _ = pearsonr(filtered_y_true.flatten(), filtered_y_pred.flatten())
print(f"Pearson correlation coefficient for filtered: {corr_filtered}")
corrsick_filtered, _ = pearsonr(filtered_y_true_sick.flatten(), filtered_y_pred_sick.flatten())
print(f"Pearson correlation coefficient for filtered and sick: {corrsick_filtered}")
# Out:
# Pearson correlation coefficient for filtered: 0.468249825770356
# Pearson correlation coefficient for filtered and sick: 0.474453652922908

# %%
import numpy as np

x = np.array(true_labels.numpy().flatten()) 
y = np.array(predictions.flatten()) 

m, q = np.polyfit(x, y, 1) 
print("Coefficiente angolare (m):", m)

x_sick = np.array(true_labels_sick.numpy().flatten())  
y_sick = np.array(predictions_sick.flatten()) 

m_sick, q = np.polyfit(x_sick, y_sick, 1)  
print("Coefficiente angolare (m):", m_sick)
# Out:
# Coefficiente angolare (m): 0.22835468762798405
# Coefficiente angolare (m): 0.18562635599028168

# %%
m_filtered = np.polyfit(np.array(filtered_y_true_giorni.flatten()), filtered_y_pred_giorni.flatten(), 1)[0]
print("Coefficiente angolare (m) for filtered:", m_filtered)
m_filtered_sick = np.polyfit(np.array(filtered_y_true_sick.flatten()), filtered_y_pred_sick.flatten(), 1)[0]
print("Coefficiente angolare (m) for filtered sick:", m_filtered_sick)
# Out:
# Coefficiente angolare (m) for filtered: 0.23723745715687442
# Coefficiente angolare (m) for filtered sick: 0.23086274229971937

# %%
len(true_labels)
# Out:
# 3501

# %%
import scipy.stats as stats

def calculate_p_value(R_squared, n, k):
    F_stat = (R_squared / k) / ((1 - R_squared) / (n - k - 1))
    
    p_value = 1 - stats.f.cdf(F_stat, dfn=k, dfd=n-k-1)
    
    return p_value

R_squared = r2
n = len(true_labels) 
k = 1   

p_value = calculate_p_value(R_squared, n, k)
print(f"P-value: {p_value}")

R_squared_sick = r2_sick
n_sick = len(true_labels_sick) 
k = 1   

p_value_sick = calculate_p_value(R_squared_sick, n_sick, k)
print(f"P-value: {p_value_sick}")
# Out:
# P-value: 1.1102230246251565e-16
# P-value: 1.1102230246251565e-16

# %% [markdown]
# Computation of MAE and MSE for the weeks

# %%
predictions_settimane = np.floor(predictions_giorni / 7)
true_labels_settimane = np.floor(true_labels_giorni / 7)
mse_settimane = mean_squared_error(true_labels_settimane, predictions_settimane)
mae_settimane = mean_absolute_error(true_labels_settimane, predictions_settimane)
print(f"Mean Squared Error (MSE): {mse_settimane}")
print(f"Mean Absolute Error (MAE): {mae_settimane}")

predictions_settimane_sick = np.floor(predictions_giorni_sick / 7)
true_labels_settimane_sick = np.floor(true_labels_giorni_sick / 7)
mse_settimane_sick = mean_squared_error(true_labels_settimane_sick, predictions_settimane_sick)
mae_settimane_sick = mean_absolute_error(true_labels_settimane_sick, predictions_settimane_sick)
print(f"Mean Squared Error (MSE) for sick: {mse_settimane_sick}")
print(f"Mean Absolute Error (MAE) for sick: {mae_settimane_sick}")

plt.figure(figsize=(8, 8))
plt.scatter(true_labels_settimane, predictions_settimane, color='blue')
min_val = min(min(true_labels_settimane_sick), min(predictions_settimane_sick))
max_val = max(max(true_labels_settimane), max(predictions_settimane))
plt.xlim([min_val, max_val])
plt.ylim([min_val, max_val])
plt.plot([min_val, max_val], [min_val, max_val], color='red', linestyle='--')
plt.xlabel("True Labels")
plt.ylabel("Predictions")
plt.title("True Labels vs Predictions")
plt.grid()
plt.show()
# Out:
# Mean Squared Error (MSE): 2.5107112253641817
# Mean Absolute Error (MAE): 1.2213653241930877
# Mean Squared Error (MSE) for sick: 9.66936114732725
# Mean Absolute Error (MAE) for sick: 2.3734028683181227

# %%
lower = np.percentile(true_labels_settimane, 5)
upper = np.percentile(true_labels_settimane, 95)
print(lower)
print(upper)

mask = (true_labels_settimane >= lower) & (true_labels_settimane <= upper)
mask_sick = (true_labels_settimane_sick >= lower) & (true_labels_settimane_sick <= upper)

filtered_y_true_settimane = np.array(true_labels_settimane)[mask]
filtered_y_pred_settimane = np.array(predictions_settimane)[mask]
filtered_y_true_sick = np.array(true_labels_settimane_sick)[mask_sick]
filtered_y_pred_sick = np.array(predictions_settimane_sick)[mask_sick]

mse = mean_squared_error(filtered_y_true_settimane, filtered_y_pred_settimane)
mae = mean_absolute_error(filtered_y_true_settimane, filtered_y_pred_settimane)

print(f"Mean Squared Error (MSE): {mse}")
print(f"Mean Absolute Error (MAE): {mae}")

mse_sick = mean_squared_error(filtered_y_true_sick, filtered_y_pred_sick)
mae_sick = mean_absolute_error(filtered_y_true_sick, filtered_y_pred_sick)

print(f"Mean Squared Error (MSE) for sick: {mse_sick}")
print(f"Mean Absolute Error (MAE) for sick: {mae_sick}")

plt.figure(figsize=(8, 8))
plt.scatter(filtered_y_true_settimane, filtered_y_pred_settimane, color='blue', label='Healthy')
min_val = min(min(filtered_y_true_sick), min(filtered_y_pred_sick))
max_val = max(max(filtered_y_true_settimane), max(filtered_y_pred_settimane))
plt.plot([min_val, max_val], [min_val, max_val], color='red', linestyle='--')
plt.xlim(min_val, max_val)
plt.xlabel("True Values")
plt.ylabel("Predictions")
plt.title("Filtered Predictions vs. True Values")
plt.legend()
plt.show()
# Out:
# 34.0
# 40.0
# Mean Squared Error (MSE): 2.1055472263868067
# Mean Absolute Error (MAE): 1.1250374812593704
# Mean Squared Error (MSE) for sick: 2.7137037037037035
# Mean Absolute Error (MAE) for sick: 1.3337037037037036

# %%
plt.figure(figsize=(8, 8))
plt.scatter(true_labels_settimane_sick, predictions_settimane_sick, color='orange')
min_val = min(min(true_labels_settimane_sick), min(predictions_settimane_sick))
max_val = max(max(true_labels_settimane), max(predictions_settimane))
plt.xlim([min_val, max_val])
plt.ylim([min_val, max_val])
plt.plot([min_val, max_val], [min_val, max_val], color='red', linestyle='--')
plt.xlabel("True Labels")
plt.ylabel("Predictions")
plt.title("True Labels vs Predictions")
plt.grid()
plt.show()

# %%
plt.figure(figsize=(8, 8))
plt.scatter(filtered_y_true_sick, filtered_y_pred_sick, color='orange', label='Sick')
min_val = min(min(filtered_y_true_sick), min(filtered_y_pred_sick))
max_val = max(max(filtered_y_true_settimane), max(filtered_y_pred_settimane))
plt.plot([min_val, max_val], [min_val, max_val], color='red', linestyle='--')
plt.xlim(min_val, max_val)
plt.xlabel("True Values")
plt.ylabel("Predictions")
plt.title("Filtered Predictions vs. True Values")
plt.legend()
plt.show()
